# %%
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import numpy as np
# ----> 2 import pandas as pd
#
# ModuleNotFoundError: No module named 'pandas'

# %%
# !pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...

# %%
import numpy as np
import pandas as pd

# %%
dataset = pd.read_csv("titanic.csv")

# %%
dataset.head(3)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S

# %%
dataset["Age"].mean()
# Out:
# np.float64(29.69911764705882)

# %%
np.mean(dataset["Age"])
# Out:
# np.float64(29.69911764705882)

# %%
# !pip install jedi jupyterlab-lsp python-lsp-server
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    -------------------------- ------------- 1.0/1.6 MB 4.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 4.7 MB/s  0:00:00
# ...
#    ---------------------------------------- 0.0/1.4 MB ? eta -:--:--
#    ---------------------- ----------------- 0.8/1.4 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.4/1.4 MB 3.3 MB/s  0:00:00
# ...
#
#    ------ ---------------------------------  2/12 [pytokens]
#    ------------- --------------------------  4/12 [pathspec]
#    ------------- --------------------------  4/12 [pathspec]
#    ------------- --------------------------  4/12 [pathspec]
#    -------------------- -------------------  6/12 [python-lsp-jsonrpc]
#    ----------------------- ----------------  7/12 [importlib-metadata]
# ...

# %%
np
